# %%
#Örnek 6.1: Basit bir Yapay Zekâ uygulaması

import numpy as np
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix,classification_report

data = np.genfromtxt('bank_note_data.txt',delimiter=',')
y = data[:,4]
X = data[:,0:4]

# Bu kısmını kitaptan bakarak yazmanız öğrenmeniz açısından
# oldukça faydalı olacağı için eklenmemiştir.

predictions = model.predict_classes(scaled_X_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_20 (Dense)             (None, 8)                 40
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 9
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 71
# Trainable params: 71
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 0s - loss: 0.6930 - accuracy: 0.5306
# Epoch 2/50
#  - 0s - loss: 0.6900 - accuracy: 0.6239
# Epoch 3/50
#  - 0s - loss: 0.6873 - accuracy: 0.5802
# Epoch 4/50
#  - 0s - loss: 0.6840 - accuracy: 0.5734
# Epoch 5/50
#  - 0s - loss: 0.6798 - accuracy: 0.5850
# Epoch 6/50
#  - 0s - loss: 0.6736 - accuracy: 0.6822
# Epoch 7/50
#  - 0s - loss: 0.6645 - accuracy: 0.7026
# Epoch 8/50
#  - 0s - loss: 0.6516 - accuracy: 0.7221
# Epoch 9/50
#  - 0s - loss: 0.6346 - accuracy: 0.7405
# Epoch 10/50
#  - 0s - loss: 0.6148 - accuracy: 0.7376
# Epoch 11/50
#  - 0s - loss: 0.5888 - accuracy: 0.7473
# Epoch 12/50
#  - 0s - loss: 0.5620 - accuracy: 0.7609
# Epoch 13/50
#  - 0s - loss: 0.5335 - accuracy: 0.7843
# Epoch 14/50
#  - 0s - loss: 0.5044 - accuracy: 0.8037
# Epoch 15/50
#  - 0s - loss: 0.4760 - accuracy: 0.8163
# Epoch 16/50
#  - 0s - loss: 0.4510 - accuracy: 0.8377
# Epoch 17/50
#  - 0s - loss: 0.4250 - accuracy: 0.8513
# Epoch 18/50
#  - 0s - loss: 0.4021 - accuracy: 0.8630
# Epoch 19/50
#  - 0s - loss: 0.3800 - accuracy: 0.8756
# Epoch 20/50
#  - 0s - loss: 0.3598 - accuracy: 0.8805
# Epoch 21/50
#  - 0s - loss: 0.3402 - accuracy: 0.8863
# Epoch 22/50
#  - 0s - loss: 0.3242 - accuracy: 0.8941
# Epoch 23/50
#  - 0s - loss: 0.3054 - accuracy: 0.8999
# Epoch 24/50
#  - 0s - loss: 0.2909 - accuracy: 0.8999
# Epoch 25/50
#  - 0s - loss: 0.2790 - accuracy: 0.9077
# Epoch 26/50
#  - 0s - loss: 0.2592 - accuracy: 0.9106
# Epoch 27/50
#  - 0s - loss: 0.2467 - accuracy: 0.9242
# Epoch 28/50
#  - 0s - loss: 0.2332 - accuracy: 0.9252
# Epoch 29/50
#  - 0s - loss: 0.2229 - accuracy: 0.9310
# Epoch 30/50
#  - 0s - loss: 0.2099 - accuracy: 0.9407
# Epoch 31/50
#  - 0s - loss: 0.1995 - accuracy: 0.9300
# Epoch 32/50
#  - 0s - loss: 0.1885 - accuracy: 0.9456
# Epoch 33/50
#  - 0s - loss: 0.1792 - accuracy: 0.9427
# Epoch 34/50
#  - 0s - loss: 0.1703 - accuracy: 0.9485
# Epoch 35/50
#  - 0s - loss: 0.1618 - accuracy: 0.9485
# Epoch 36/50
#  - 0s - loss: 0.1564 - accuracy: 0.9456
# Epoch 37/50
#  - 0s - loss: 0.1471 - accuracy: 0.9524
# Epoch 38/50
#  - 0s - loss: 0.1406 - accuracy: 0.9543
# Epoch 39/50
#  - 0s - loss: 0.1355 - accuracy: 0.9543
# Epoch 40/50
#  - 0s - loss: 0.1293 - accuracy: 0.9514
# Epoch 41/50
#  - 0s - loss: 0.1259 - accuracy: 0.9572
# Epoch 42/50
#  - 0s - loss: 0.1199 - accuracy: 0.9572
# Epoch 43/50
#  - 0s - loss: 0.1150 - accuracy: 0.9621
# Epoch 44/50
#  - 0s - loss: 0.1109 - accuracy: 0.9611
# Epoch 45/50
#  - 0s - loss: 0.1071 - accuracy: 0.9640
# Epoch 46/50
#  - 0s - loss: 0.1035 - accuracy: 0.9660
# Epoch 47/50
#  - 0s - loss: 0.1000 - accuracy: 0.9670
# Epoch 48/50
#  - 0s - loss: 0.0964 - accuracy: 0.9670
# Epoch 49/50
#  - 0s - loss: 0.0936 - accuracy: 0.9670
# Epoch 50/50
#  - 0s - loss: 0.0916 - accuracy: 0.9660
# *****
# [[172   7]
#  [  5 159]]
# *****
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.96      0.97       179
#          1.0       0.96      0.97      0.96       164
#
#     accuracy                           0.97       343
#    macro avg       0.96      0.97      0.96       343
# weighted avg       0.97      0.97      0.97       343
